# %%
import pandas as pd
import sqlite3 as sql

# %%
connection = sql.connect('mock_data.db')

# %%
pd.options.display.max_columns = 10

# %%
pd.read_sql('SELECT * FROM mock_data', connection)
# Out:
#        id   first_name last_name                       email      gender  \
# 0       1        Caria  Spillman  cspillman0@istockphoto.com      Female
# 1       2     Giuditta    Harses    gharses1@photobucket.com      Female
# 2       3        Alida     Furby         afurby2@histats.com      Female
# 3       4        Nefen    Mewitt       nmewitt3@illinois.edu      Female
# 4       5       Chicky    Beaver         cbeaver4@joomla.org  Non-binary
# ..    ...          ...       ...                         ...         ...
# 995   996        Allie    Downie    adowniern@altervista.org      Female
# 996   997  Konstantine   Perrone       kperronero@flickr.com      Female
# 997   998        Janna    Hayden       jhaydenrp@state.tx.us      Female
# 998   999         Gnni  Stuttard        gstuttardrq@gmpg.org        Male
# 999  1000     Raphaela   Ferrara          rferrararr@dot.gov        Male
#
#                                    iban         credit_card current_balance
# ...
