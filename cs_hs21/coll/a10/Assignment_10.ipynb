# %% [markdown]
# # Assignment 10: Visualization
#
# Please read the tasks description carefully and implement **only** what the tasks ask you to implement. Closely following the task descriptions will be beneficial, so keep your divergence in check - the test cases below each input cell are the gold standard. Finally, for this assignment, you do not need any error handling, you can assume that all input to your function will be valid.
#
# As for the other assignments, using `print` is encouraged to test your implementation but is never required. Make sure not to confuse `return` and `print` statements: If your function has to **return** something, use the `return` statement.
#
# Try to implement the tasks yourself or in a small team. If you blindly copy a solution from the Internet or other students, you will not take home any learnings. Rather, make an effort to understand the solution! Furthermore, do not modify the _test cells_ - if you do, you effectively cheat the system which is not helpful for your learning process.
#
# Some aspects of this assignment require you to <strong>self-study</strong> and do some research beyond the lecture contents - use your favorite search engine to look up documentation, usage examples, and definitions of the mentioned functions. There might be tasks where you have to read and investigate the [Python Standard Library](https://docs.python.org/3/library/) to find the documentation for a function that is used or that you want to use.
#
# This assignment will use the third-party modules  [NumPy](https://numpy.org/https://numpy.org/), [pandas](https://pandas.pydata.org/), [matplotlib](https://matplotlib.org/), [seaborn](https://seaborn.pydata.org/https://seaborn.pydata.org/), and [scikit-learn](https://scikit-learn.org/https://scikit-learn.org/).

# %% [markdown]
# <p style="padding: 1em; background-color: #ffa62f;">This Assignment will not have Test Cells like the others.
# Usually, if the plot fulfills als requirements and looks like the template, you did implement it correct.y</p>

# %%
# We'll import pandas and matplotlib:

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import seaborn as sns

# %% [markdown]
# ---
# # Task 1: Fruits
#
# Use the given function `get_fruits()` to generate a DataFrame with a few examples of fruit consumption in one week.

# %%
def get_fruits():
    """
    This function returns a dataframe on which we'll operate
    later on.
    """
    return pd.DataFrame(
        {
            "Monday": [10, 15, 11], 
            "Tuesday": [5, 8, 13], 
            "Wednesday": [10, 3, 8],
            "Thursday": [11, 10, 19],
            "Friday": [20, 30, 23], 
            "Saturday": [30, 60, 99],
            "Sunday": [35, 75, 1]
        }, 
        index=["Apple", "Banana", "Cherry"]
    )

fruits = get_fruits()

# %% [markdown]
# ---
# ## Task 1.1
#
# Create the following plot based on the `fruits` DataFrame:
#
# * Use a figure size of 8x6.
# * Draw a line plot of the three fruits *Apple*, *Banana*, and *Cherry*.
# * Use the colors green, blue, and red, respectively.
# * The x-axis should contain the week days.
# * Add the legend.
#
# __Hint__: Look at the dataframe and identify which columns to draw and identify the targets for the x-and y-axis.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# ⬇️ Add your code below this line ⬇️



# ⬆️ Add your code above this line ⬆️

# %% [markdown]
# ---
# ## Task 1.2
#
# Create a bar plot of the food consumption.
#
# * Use a figure size of 8x6.
# * Use the week days on the x-axis.
# * Use the individual consumption on the y-axis.
# * Use the same colors as above.
# * The xticks must be **exacly** in the middle of the blue bar.
#
# __Hint__: Be careful with the placement of the x-ticks.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# ⬇️ Add your code below this line ⬇️



# ⬆️ Add your code above this line ⬆️

# %% [markdown]
# ---
# ## Task 1.3
#
# Identify the type of plots and recreate it!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# ⬇️ Add your code below this line ⬇️



# ⬆️ Add your code above this line ⬆️

# %% [markdown]
# ---
# # Task 2
#
# Use the given function `load_iris()` to load the IRIS dataset into a dataframe called `IRIS`.

# %%
def load_iris():
    import sklearn.datasets
    iris = sklearn.datasets.load_iris(as_frame=True)
    df = iris["data"].rename(columns={c: c[:-5] for c in iris['data'].columns})
    df['flower'] = iris['target'].apply(lambda f: iris['target_names'][f])
    df = df.set_index('flower')
    return df

IRIS = load_iris()

# %% [markdown]
# ---
# ## Task 2.1
#
#
# Plot the **features** of each column _using Seaborn_ (sepal/petal length/width) as a boxplot for each type of flower.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# ⬇️ Add your code below this line ⬇️



# ⬆️ Add your code above this line ⬆️

# %% [markdown]
# ---
# ## Task 2.2
#
# We want to identify correlations between features for the all flowers together.
#
# For this, we want to create a _regression plot_ using _Seaborn_ with a cubic (`order=3`) regression function for each combination of the available features.
#
# Do you see a link between specific features?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# ⬇️ Add your code below this line ⬇️



# ⬆️ Add your code above this line ⬆️
