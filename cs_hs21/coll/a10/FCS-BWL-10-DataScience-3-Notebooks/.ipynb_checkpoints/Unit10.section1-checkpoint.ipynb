# %% [markdown]
# # Lecture 10
#
# # Section 1: Data Visualization with Matplotlib

# %% [markdown]
# ## A basic plot
#
# - To make a basic plot you can use `.plot()`
# - Here we plot a single point
# - The default style used is the line style
# - Nothing is shown because you can't really visualize a single point this way

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (18,6)

# %%
plt.plot(3, 2)
plt.show()

# %% [markdown]
# ### Basic plot: point
#
# - We now specify that we want this point visualized as a point
# - For that we use '.' as third argument (called `fmt`)
# - There is a **huge** amount of options and combinations

# %%
import matplotlib.pyplot as plt
plt.plot(3, 2, ".")
plt.show()

# %% [markdown]
# ### Basic plot: format string (bottom of the page)
#
# [Documentation][1]
#
# [1]: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html

# %%
import matplotlib.pyplot as plt
plt.plot(3, 2, 'vm')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(3, 2, 'Hm')
plt.show()

# %% [markdown]
# ## Lineplot: connecting the dots

# %%
import matplotlib.pyplot as plt
plt.plot([3, 5, 2], [2, 0, 8], 'vc-')
plt.show()

# %% [markdown]
# ## Some matplotlib terminology

# %% [markdown]
# It is important to understand some basic matplotlib concepts, i.e., the anatomy of a matplotlib figure
#
# ![Anatomy of a figure](data:image/png;base64,...)
#
# Source: https://towardsdatascience.com/matplotlib-seaborn-pandas-an-ideal-amalgamation-for-statistical-data-visualisation-f619c8e8baa3

# %% [markdown]
# ## Axes
#
# Axes: [Documentation][1]
#
# [1]: https://matplotlib.org/stable/api/axes_api.html
#
#
# - Here used `plt.gca()` to get an `Axes` object
# - gca = ``get current axes``
#
# Axis: [Documentation][2]
#
# [2]: https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.axis.html
#
# - We then set the axis min and max values

# %%
import matplotlib.pyplot as plt
# create a new figure
plt.figure()
# plot the point (3,2) using the circle marker
plt.plot(3, 2, 'o')
# get the current axes
ax = plt.gca()
# Set axis properties [xmin, xmax, ymin, ymax]
ax.axis([0, 6, 0, 10])

# %% [markdown]
# Here is an example of a plot with multiple points.

# %%
import matplotlib.pyplot as plt
# create a new figure
plt.figure()
# plot the point (1.5, 1.5) using the circle marker
plt.plot(1.5, 1.5, 'o')
# plot the point (2, 2) using the circle marker
plt.plot(2, 2, 'o')
# plot the point (2.5, 2.5) using the circle marker
plt.plot(2.5, 2.5, 'vc')
plt.show()

# %% [markdown]
# ## Scatter plots: pyplot.scatter
#
# [Documentation][1]
#
# [1]: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html
#
# - We specify the x and y coordinates
# - Here each point has the same value for x and y
# - We also specify the colors for each point
# - `s=100` specifies the size of the dots

# %%
import numpy as np
import matplotlib.pyplot as plt
x = [1,2,3,4,5,6,7,8]
y = x
# create a list of colors for each point to have
colors = ['purple']*(len(x)-1)
print(colors)
colors.append('pink')
#plt.figure()
# plot the point with size 100 and chosen colors
plt.scatter(x, y, s=100, c=colors)
plt.show()

# %%
# What is plotted for the following code?
import numpy as np
import matplotlib.pyplot as plt
x = [1,2,3,4,5,6,7,8]
y = x
colors = ["orange" if x % 2 == 0 else "black" for x in range(len(x))]
plt.figure()
plt.scatter(x, y, s=100, c=colors)
plt.show()

# %% [markdown]
# ### Adding labels
#
# - Adding labels is easy: use `.xlabel` and `.ylabel`
# - For the title simply use `.title`
# - But where did the `label="Tall students"` go?

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5,6,7,8]
y = x
plt.figure()
plt.scatter(x[:2], y[:2], s=100, c='red', label='Tall students')
plt.scatter(x[2:], y[2:], s=100, c='blue', label='Short students')
# add a label to the x axis
plt.xlabel('The number of times the child kicked a ball')
# add a label to the y axis
plt.ylabel('The grade of the student')
# add a title
plt.title('Relationship between ball kicking and grades')
plt.show()

# %% [markdown]
# ### Adding a legend
#
# [Documentation][1]
#
# [1]: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html
#
# - We forgot to add the legend to the plot
# - To do that, we have to call `.legend()`
# - The legend is then drawn such that it has minimal overlap

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5,6,7,8]
y = x
plt.figure()
plt.scatter(x[:2], y[:2], s=100, c='red', label='Tall students')
plt.scatter(x[2:], y[2:], s=100, c='blue', label='Short students')
plt.xlabel('The number of times the child kicked a ball')
plt.ylabel('The grade of the student')
plt.title('Relationship between ball kicking and grades')
#### add the legend! ####
plt.legend()
plt.show()

# %% [markdown]
# ### Customizing a legend
#
# - Here we disabled the frame around the legend
# - We also set the location to `4`, which means lower right
# - For full location options check the [documentation][1]
#
# [1]: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.legend.html

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5,6,7,8]
y = x
plt.figure()
plt.scatter(x[:2], y[:2], s=100, c='red', label='Tall students')
plt.scatter(x[2:], y[2:], s=100, c='blue', label='Short students')
plt.xlabel('The number of times the child kicked a ball')
plt.ylabel('The grade of the student')
plt.title('Relationship between ball kicking and grades')
#### add the legend! ####
plt.legend(loc=4, frameon=False, title='Legend')
plt.show()

# %% [markdown]
# ### Lineplot: multiple lines
#
# - Here we have plotted two lines
# - We used `numpy` to generate some data for plotting
# - We specified that these are lines by using the `"-"` in the format string

# %%
#import numpy as np
import matplotlib.pyplot as plt
linear_data = [1,2,3,4,5,6,7,8]
exponential_data = [ x**2 for x in linear_data ]
# plot the linear data and the exponential data
plt.plot(linear_data, 'm-o', exponential_data, '-v')
plt.show()

# %% [markdown]
# ### Lineplot: filling area between lines
#
# [Documentation][1]
#
# [1]: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.fill_between.html
#
# - We use `.fill_between` to fill the area
# - The first argument needs to be an iterable of the x-coordinates
# - The second and third argument are the y-coordinates of the two lines - the arguments must all have the same length

# %%
#import numpy as np
import matplotlib.pyplot as plt

linear_data = [1,2,3,4,5,6,7,8]
exponential_data = [ x**2 for x in linear_data ]
# plot the linear data and the exponential data
plt.plot(linear_data, 'm-o', exponential_data, '-v')
plt.gca().fill_between(range(len(linear_data)), 
                       linear_data, exponential_data, 
                       facecolor='blue', 
                       alpha=0.25)
plt.show()

# %%
#import numpy as np
import matplotlib.pyplot as plt

linear_data = [1,2,3,4,5,6,7,8]
exponential_data = [ x**2 for x in linear_data ]
# plot the linear data and the exponential data
plt.plot(linear_data, 'm-o', exponential_data, '-v')
plt.gca().fill_between(range(8), linear_data, exponential_data, facecolor='cyan', alpha=0.1)
plt.show()

# %% [markdown]
# How does the plot change when we use different values for the fill area?

# %%
#import numpy as np
import matplotlib.pyplot as plt
linear_data = [1,2,3,4,5,6,7,8]
exponential_data = [ x**2 for x in linear_data ]
plt.plot(linear_data, 'm-o', exponential_data, '-v')
plt.gca().fill_between(range(len(linear_data)), 
                       [4, 14, 4, 14, 4, 14, 4, 14], [40, 30, 40, 30, 40, 30, 40, 30],
                       facecolor='blue', alpha=0.25)
plt.show()

# %% [markdown]
# ### Lineplot: dates
#
# - We can use dates for the coordinates
# - Here we get the dates by using `np.arange`
# - Then we can plot exactly the same way that we have already seen

# %%
import numpy as np
import matplotlib.pyplot as plt
linear_data = [1,2,3,4]
exponential_data = [ x**2 for x in linear_data ]
observation_dates = np.arange('2020-04-27', '2020-05-01', dtype='datetime64[D]')
print(observation_dates)
plt.plot(observation_dates, linear_data, '-o',  observation_dates, exponential_data, '-o')
plt.show()

# %% [markdown]
# ### Lineplot: label rotation
#
# - First we have to get the x-axis, as an object
# - After that we can get the labels on the axis and rotate them
# - This makes our graph more readable!

# %%
import numpy as np
import matplotlib.pyplot as plt
linear_data = [1,2,3,4]
exponential_data = [ x**2 for x in linear_data ]
observation_dates = np.arange('2020-04-27', '2020-05-01', dtype='datetime64[D]')
print(observation_dates)
plt.plot(observation_dates, linear_data, '-o',  observation_dates, exponential_data, '-o')
x = plt.gca().xaxis
# access the x-axis
# rotate the tick labels for the x axis
for item in x.get_ticklabels():
    item.set_rotation(45)
plt.show()

# %% [markdown]
# ## Bar Chart
#
# - All we have to do to make a bar chart is to call `.bar`
# - Here we specify a width of 0.3 for each bar

# %%
import matplotlib.pyplot as plt
linear_data = [1,2,3,4]
xvals = range(len(linear_data))
plt.bar(xvals, linear_data, width = 0.3)
plt.show()

# %% [markdown]
# ### Bar Chart: Multiple
#
# - Note how we shift the red bars by +0.3
# - This is because our blue bars have a width of 0.3, and we want the red ones immediately next to them

# %%
import matplotlib.pyplot as plt
linear_data = [1,2,3,4]
exponential_data = [ x**2 for x in linear_data ]
xvals = range(len(linear_data))
plt.bar(xvals, linear_data, width = 0.3)
new_xvals = []
# plot another set of bars, adjusting the new xvals to make up for the first set of bars plotted
for item in xvals:
    new_xvals.append(item+0.3)
print(new_xvals)
plt.bar(new_xvals, exponential_data, width = 0.3 ,color='red')
plt.show()

# %% [markdown]
# ### Bar Chart: Plotting the error
#
# - Here we visualized the error
# - We did this by passing the errors in the argument `yerr`

# %%
from random import randint
import matplotlib.pyplot as plt
linear_data = [1,2,3,4]
xvals = range(len(linear_data))
linear_err = [randint(0,15) for x in range(len(linear_data))]
print(linear_err)
# This will plot a new set of bars with errorbars using the list of random error values
plt.bar(xvals, linear_data, width = 0.3, yerr=linear_err)
plt.show()

# %% [markdown]
# ### Bar Chart: Stacked
#
# - We made a stacked chart by not shifting the red bars
# - Compare this to the example where we had the bars side-by-side and this example should become very clear

# %%
from random import randint
import matplotlib.pyplot as plt
linear_data = [1,2,3,4]
exponential_data = [ x**2 for x in linear_data ]
xvals = range(len(linear_data))
plt.bar(xvals, linear_data, width = 0.3, color='b')
plt.bar(xvals, exponential_data, width = 0.3, bottom=linear_data, color='r')
plt.show()

# %% [markdown]
# ### Bar Chart: Horizontal
#
# - To make a horizontal bar chart all we have to do is use `.barh` instead of `.bar`
# - Everything works exactly the same as for vertical bar charts

# %%
from random import randint
import matplotlib.pyplot as plt
linear_data = [1,2,3,4]
exponential_data = [ x**2 for x in linear_data ]
xvals = range(len(linear_data))
plt.barh(xvals, linear_data, height = 0.3, color='b')
plt.barh(xvals, exponential_data, height = 0.3, left=linear_data, color='r')
plt.show()

# %% [markdown]
# ## Subplots
#
# - The first three arguments describe the structure of the subplot
# - `nrows, ncols, index`: Creates a plot with the specified number of rows and columns, at the index
# - For 1 as the index the position is top left, and it increases from left to right

# %%
import matplotlib.pyplot as plt
plt.subplot(1, 2, 1)
linear_data = [1,2,3,4,5,6,7,8]
plt.plot(linear_data, '-o')
exponential_data = [ x**2 for x in linear_data ]
plt.subplot(1, 2, 2)
plt.plot(exponential_data, '-o')
plt.show()

# %% [markdown]
# ### Subplots: Shared axis
#
# - We use the `share` argument to specify the shared axis
# - This way it become easier to compare graphs

# %%
import matplotlib.pyplot as plt
import numpy as np
linear_data = [1,2,3,4,5,6,7,8]
exponential_data = [ x**2 for x in linear_data ]
ax1 = plt.subplot(1, 2, 1)
plt.plot(linear_data, '-o')
# pass sharey=ax1 to ensure the two subplots share the same y axis
ax2 = plt.subplot(1, 2, 2, sharey=ax1)
plt.plot(exponential_data, '-x')
plt.show()

# %% [markdown]
# ### Subplots: 3x3, ...
#
# - We can share both axes!
# - In this example you can see a 3x3 grid of subplots, all sharing the same axes

# %%
import matplotlib.pyplot as plt
import numpy as np
linear_data = [1,2,3,4,5,6,7,8]
exponential_data = [ x**2 for x in linear_data]
qubic_data = [ x**3 for x in linear_data]
# create a 3x3 grid of subplots
fig, ((ax1,ax2,ax3), (ax4,ax5,ax6), (ax7,ax8,ax9)) = plt.subplots(3, 3, sharex=True, sharey=True)
# plot the linear_data on the 5th subplot axes 
ax1.plot(linear_data, '-')
ax5.plot(exponential_data, '--' )
ax9.plot(qubic_data, '.')
plt.show()

# %% [markdown]
# ## Histogram
#
# - We draw n random values and plot a histogram with 100 buckets
# - Here we plot the histograms for n=10, 100, 1000 and 10000
# - The main work is done by calling `.hist`

# %%
import matplotlib.pyplot as plt
import numpy as np
# create 2x2 grid of axis subplots
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharex=True)
axs = [ax1,ax2,ax3,ax4]
# draw n samples and plot
for n in range(0,len(axs)):
    sample_size = 10**(n+1)
    sample = np.random.normal(loc=0.0, scale=1.0, size=sample_size)
    axs[n].hist(sample, bins=100)
    axs[n].set_title('n={}'.format(sample_size))
plt.show()

# %% [markdown]
# ## Boxplot
#
# - Again, all we have to do to make a boxplot is call `df.boxplot()`
# - The big function is just to help with the labels so the graph is easier to understand
# - Example, 25\% marker: a quarter of our points has a value that is equal to or lower -1.7

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

def annotate_boxplot(bpdict, annotate_params=None, x_offset=0.05, x_loc=0, text_offset_x=35, text_offset_y=20):
    annotate_params = dict(xytext=(text_offset_x, text_offset_y), textcoords='offset points', arrowprops={'arrowstyle':'->'})
    plt.annotate('Median', (x_loc + 1 + x_offset, bpdict['medians'][x_loc].get_ydata()[0]), **annotate_params)
    plt.annotate('25%', (x_loc + 1 + x_offset, bpdict['boxes'][x_loc].get_ydata()[0]), **annotate_params)
    plt.annotate('75%', (x_loc + 1 + x_offset, bpdict['boxes'][x_loc].get_ydata()[2]), **annotate_params)
    plt.annotate('5%', (x_loc + 1 + x_offset, bpdict['caps'][x_loc*2].get_ydata()[0]), **annotate_params)
    plt.annotate('95%', (x_loc + 1 + x_offset, bpdict['caps'][(x_loc*2)+1].get_ydata()[0]), **annotate_params)
    plt.show()
   

df = pd.DataFrame({'col1': np.random.normal(size=100),
                   'col2': np.random.normal(scale=2, size=100)})

bpdict = df.boxplot(whis=[5, 95], return_type='dict')
annotate_boxplot(bpdict, x_loc=1)

# %% [markdown]
# ## Heatmap
#
# - And once again, very simple to make a basic plot: `.hist2d`
# - The "warmer" the color the more datapoints
# - `np.random.random` returns values between 0 and 1

# %%
import matplotlib.pyplot as plt
import numpy as np
Y = np.random.normal(loc=0.0, scale=1.0, size=10000)
X = np.random.random(size=10000)
plt.hist2d(X, Y, bins=25)
plt.show()
